# %% [markdown]
# # Ex1 - Filtering and Sorting Data

# %% [markdown]
# This time we are going to pull data directly from the internet.
# Special thanks to: https://github.com/justmarkham for sharing the dataset and materials.
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv).

# %% [markdown]
# ### Step 3. Assign it to a variable called chipo.

# %%
chipo = pd.read_csv("https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv", sep="\t")
chipo.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %% [markdown]
# ### Step 4. How many products cost more than $10.00?

# %%
chipo["float_price"] = chipo["item_price"].apply(lambda x: float(x[1:]))
chipo.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price  float_price
# 0                                                NaN     $2.39          2.39
# 1                                       [Clementine]     $3.39          3.39
# 2                                            [Apple]     $3.39          3.39
# 3                                                NaN     $2.39          2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98         16.98

# %%
chipo["product_price"] = chipo["float_price"] / chipo["quantity"]
chipo.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price  float_price  \
# 0                                                NaN     $2.39          2.39
# 1                                       [Clementine]     $3.39          3.39
# 2                                            [Apple]     $3.39          3.39
# 3                                                NaN     $2.39          2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98         16.98
#
#    product_price
# 0           2.39
# 1           3.39
# 2           3.39
# 3           2.39
# 4           8.49

# %%
chipo[chipo.item_name == "Izze"]
# Out:
#       order_id  quantity item_name choice_description item_price  float_price  \
# 1            1         1      Izze       [Clementine]     $3.39          3.39
# 24          12         1      Izze       [Grapefruit]     $3.39          3.39
# 47          21         1      Izze       [Blackberry]     $3.39          3.39
# 66          30         1      Izze       [Blackberry]     $3.39          3.39
# 359        155         1      Izze       [Blackberry]     $3.39          3.39
# 360        155         1      Izze       [Grapefruit]     $3.39          3.39
# 430        186         1      Izze       [Grapefruit]     $3.39          3.39
# 579        237         1      Izze       [Clementine]     $3.39          3.39
# 580        237         1      Izze       [Grapefruit]     $3.39          3.39
# 1059       436         1      Izze       [Clementine]     $3.39          3.39
# 1213       495         1      Izze       [Clementine]     $3.39          3.39
# ...

# %%
filtered = chipo.drop_duplicates(["item_name", "choice_description"])
filtered[filtered.item_name == "Izze"]
# Out:
#     order_id  quantity item_name choice_description item_price  float_price  \
# 1          1         1      Izze       [Clementine]     $3.39          3.39
# 24        12         1      Izze       [Grapefruit]     $3.39          3.39
# 47        21         1      Izze       [Blackberry]     $3.39          3.39
#
#     product_price
# 1            3.39
# 24           3.39
# 47           3.39

# %%
filtered = filtered[filtered.product_price > 10][["item_name", "choice_description", "product_price"]].reset_index(drop=True)

# %%
filtered
# Out:
#            item_name                                 choice_description  \
# 0       Chicken Bowl  [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...
# 1      Steak Burrito  [Tomatillo Red Chili Salsa, [Fajita Vegetables...
# 2       Chicken Bowl  [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...
# 3    Chicken Burrito  [[Tomatillo-Green Chili Salsa (Medium), Tomati...
# 4      Barbacoa Bowl  [Roasted Chili Corn Salsa, [Fajita Vegetables,...
# ..               ...                                                ...
# 702    Carnitas Bowl  [Roasted Chili Corn Salsa, [Rice, Sour Cream, ...
# 703    Barbacoa Bowl  [Roasted Chili Corn Salsa, [Pinto Beans, Sour ...
# 704    Steak Burrito  [Tomatillo Green Chili Salsa, [Rice, Cheese, S...
# 705    Steak Burrito  [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...
# 706   Veggie Burrito  [Tomatillo Green Chili Salsa, [Rice, Fajita Ve...
#
#      product_price
# 0            10.98
# 1            11.75
# 2            11.25
# 3            10.98
# ...

# %% [markdown]
# ### Step 5. What is the price of each item?
# ###### print a data frame with only three columns item_name choice_description and product_price

# %%
filtered[["item_name", "choice_description", "product_price"]]
# Out:
#            item_name                                 choice_description  \
# 0       Chicken Bowl  [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...
# 1      Steak Burrito  [Tomatillo Red Chili Salsa, [Fajita Vegetables...
# 2       Chicken Bowl  [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...
# 3    Chicken Burrito  [[Tomatillo-Green Chili Salsa (Medium), Tomati...
# 4      Barbacoa Bowl  [Roasted Chili Corn Salsa, [Fajita Vegetables,...
# ..               ...                                                ...
# 702    Carnitas Bowl  [Roasted Chili Corn Salsa, [Rice, Sour Cream, ...
# 703    Barbacoa Bowl  [Roasted Chili Corn Salsa, [Pinto Beans, Sour ...
# 704    Steak Burrito  [Tomatillo Green Chili Salsa, [Rice, Cheese, S...
# 705    Steak Burrito  [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...
# 706   Veggie Burrito  [Tomatillo Green Chili Salsa, [Rice, Fajita Ve...
#
#      product_price
# 0            10.98
# 1            11.75
# 2            11.25
# 3            10.98
# ...

# %% [markdown]
# ### Step 6. Sort by the name of the item

# %%
chipo.sort_values(by="item_name")
# Out:
#       order_id  quantity          item_name  \
# 3389      1360         2  6 Pack Soft Drink
# 341        148         1  6 Pack Soft Drink
# 1849       749         1  6 Pack Soft Drink
# 1860       754         1  6 Pack Soft Drink
# 2713      1076         1  6 Pack Soft Drink
# ...        ...       ...                ...
# 2384       948         1  Veggie Soft Tacos
# 781        322         1  Veggie Soft Tacos
# 2851      1132         1  Veggie Soft Tacos
# 1699       688         1  Veggie Soft Tacos
# 1395       567         1  Veggie Soft Tacos
#
#                                      choice_description item_price  \
# 3389                                        [Diet Coke]    $12.98
# 341                                         [Diet Coke]     $6.49
# 1849                                             [Coke]     $6.49
# 1860                                        [Diet Coke]     $6.49
# 2713                                             [Coke]     $6.49
# ...

# %% [markdown]
# ### Step 7. What was the quantity of the most expensive item ordered?

# %%
chipo.iloc[chipo.float_price.argmax()]["quantity"]
# Out:
# np.int64(15)

# %% [markdown]
# ### Step 8. How many times was a Veggie Salad Bowl ordered?

# %%
chipo[chipo.item_name == "Veggie Salad Bowl"].order_id.count()
# Out:
# np.int64(18)

# %% [markdown]
# ### Step 9. How many times did someone order more than one Canned Soda?

# %%
chipo[(chipo.item_name == "Canned Soda") & (chipo.quantity > 1)].shape[0]
# Out:
# 20
